# %%
import pandas as pd
# %load_ext sql

# initialize a database connection
# %sql mysql+pymysql://root:mysql@localhost/deals
# Out:
# C:\Users\Hannah\Anaconda3\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 'Connected: root@deals'

# %% [markdown]
# 9. Select all Columns from CompanyDeals view

# %%
# %%sql
# SELECT *
# FROM CompanyDeals
# Out:
# 332 rows affected.
# [('ADT Limited', 'B1', 'Western Resources, Inc.'),
#  ('ADT Limited', 'B2', 'Tyco International Ltd.'),
#  ('ADT Limited', 'T', 'ADT Limited'),
#  ('Advanta Corp.', 'A', 'Fleet Financial Group, Inc.'),
#  ('Advanta Corp.', 'T', 'Advanta Corp. Credit card unit'),
#  ('Alex. Brown Inc.', 'A', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'T', 'Alex. Brown Inc.'),
#  ('Allied Colloids Group PLC', 'T', 'Allied Colloids Group'),
#  ('Allied Colloids Group PLC', 'B1', 'Hercules Inc.'),
#  ('American First Financial Insurance Group Inc.', 'T', 'American Bankers Insurance Group Inc.'),
#  ('American First Financial Insurance Group Inc.', 'A', 'American International Group Inc.'),
#  ('American Medical Response, Inc.', 'A', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'T', 'American Medical Response, Inc.'),
#  ('American Radio Systems Corp.', 'A', 'Westinghouse Electric Corp.'),
# ...

# %% [markdown]
# 9. Select all Columns from DealValues that lists that lists the DealID, total dollar value and number of parts for each deal.

# %%
# %%sql
# SELECT *
# FROM DealValues
# Out:
# 151 rows affected.
# [(1, Decimal('5600.0000'), 1),
#  (2, Decimal('1700.0000'), 1),
#  (3, Decimal('1120.0000'), 1),
#  (4, Decimal('4000.0000'), 1),
#  (5, Decimal('1500.0000'), 1),
#  (6, Decimal('1600.0000'), 1),
#  (7, Decimal('1870.0000'), 1),
#  (8, Decimal('3700.0000'), 1),
#  (9, Decimal('1600.0000'), 1),
#  (10, Decimal('1200.0000'), 1),
#  (11, Decimal('1617.0000'), 1),
#  (12, Decimal('1360.0000'), 1),
#  (13, Decimal('1270.0000'), 1),
#  (14, Decimal('4210.0000'), 1),
#  (15, Decimal('1150.0000'), 1),
#  (16, Decimal('9700.0000'), 1),
#  (17, Decimal('1050.0000'), 1),
#  (18, Decimal('7000.0000'), 1),
#  (19, Decimal('3400.0000'), 1),
#  (20, Decimal('9500.0000'), 1),
#  (21, Decimal('6590.0000'), 1),
#  (22, Decimal('1700.0000'), 1),
#  (23, Decimal('1100.0000'), 1),
#  (24, Decimal('1355.0000'), 1),
#  (25, Decimal('10900.0000'), 1),
#  (26, Decimal('1650.0000'), 1),
#  (27, Decimal('1900.0000'), 1),
#  (28, Decimal('6500.0000'), 1),
#  (29, Decimal('1800.0000'), 1),
# ...

# %% [markdown]
# 10. Select all Columns from DealSummary that lists the DealID, DealName, number of players, total dollar value, and number of parts for each deal.

# %%
# %%sql
# SELECT *
# FROM DealSummary
# Out:
# 149 rows affected.
# [(1, 'ADT Limited', 3, Decimal('16800.0000'), 3),
#  (2, 'Alex. Brown Inc.', 2, Decimal('3400.0000'), 2),
#  (3, 'American Medical Response, Inc.', 2, Decimal('2240.0000'), 2),
#  (4, 'American Standard Companies, Inc.', 2, Decimal('8000.0000'), 2),
#  (5, 'Amphenol Corp.', 2, Decimal('3000.0000'), 2),
#  (6, 'Bankamerica Corp.', 1, Decimal('1600.0000'), 1),
#  (7, 'Berliner Kraft & Licht AG', 1, Decimal('1870.0000'), 1),
#  (8, 'Cascade Communications Corp.', 2, Decimal('7400.0000'), 2),
#  (9, 'Chancellor Broadcasting Comp.', 2, Decimal('3200.0000'), 2),
#  (10, 'Cifra S.A.', 2, Decimal('2400.0000'), 2),
#  (11, 'Coca Cola Bottling Co. of New York and Coca-Cola B', 2, Decimal('3234.0000'), 2),
#  (12, 'Dauphin Deposit Corp.', 2, Decimal('2720.0000'), 2),
#  (13, 'The Dow Chemical Company', 3, Decimal('3810.0000'), 3),
#  (14, 'DQE Inc.', 2, Decimal('8420.0000'), 2),
#  (15, 'Eller Media Corp.', 3, Decimal('3450.0000'), 3),
# ...

# %% [markdown]
# 11. Select all columns from DealsByType that lists TypeCode, number of deals, and total value of deals for each deal type.

# %%
# %%sql
# SELECT *
# FROM DealsByType
# Out:
# 6 rows affected.
# [('C/S', 80, Decimal('271794.0000')),
#  ('CM', 3, Decimal('8030.0000')),
#  ('PA', 1, Decimal('1880.0000')),
#  ('PF', 4, Decimal('27790.0000')),
#  ('SS', 59, Decimal('204658.0000')),
#  ('TO', 16, Decimal('55972.0000'))]

# %% [markdown]
# 12. Select all Columns from DealPlayers View that lists the CompanyID, Name, and Role Code for each deal. Sort the players by the RoleSortOrder.

# %%
# %%sql
# SELECT *
# FROM DealPlayers
# Out:
# 332 rows affected.
# [(277, 'Allied Colloids Group', 'T'),
#  (3, 'ADT Limited', 'T'),
#  (6, 'Alex. Brown Inc.', 'T'),
#  (11, 'American Medical Response, Inc.', 'T'),
#  (13, 'American Standard Companies, Inc.', 'T'),
#  (16, 'Amphenol Corp.', 'T'),
#  (216, 'Security Pacific Financial Services', 'T'),
#  (39, 'Cascade Communications Corp.', 'T'),
#  (43, 'Chancellor Broadcasting Comp.', 'T'),
#  (46, 'Cifra S.A.', 'T'),
#  (51, 'Coca Cola Bottling Co. of New York and Coca-Cola B', 'T'),
#  (66, 'Dauphin Deposit Corp.', 'T'),
#  (68, 'Destec Energy, Inc.', 'T'),
#  (71, 'DQE Inc.', 'T'),
#  (73, 'Eller Media Corp.', 'T'),
#  (74, 'Energy Group PLC, The', 'T'),
#  (87, 'First Financial Corp.', 'T'),
#  (89, 'First USA, Inc.', 'T'),
#  (92, 'Fort Howard Corp.', 'T'),
#  (116, 'Hughes Electronics Corp.', 'T'),
#  (98, 'Great Western Financial Corp.', 'T'),
#  (102, 'Healthsource, Inc.', 'T'),
#  (229, 'Tastemaker', 'T'),
#  (106, 'Heritage Media Corp.', 'T'),
# ...

# %% [markdown]
# 13. Select all Columns from DealsByFirm that lists the FirmID, Name, number of deals, and total value of deals for each firm.

# %%
# %%sql
# SELECT *
# FROM DealsByFirm
# Out:
# 257 rows affected.
# [(2, 'Bryan Cave', 4, Decimal('84480.0000')),
#  (3, 'Buchanan Ingersol', 1, Decimal('1000.0000')),
#  (11, 'Dechert Price & Rhoads', 2, Decimal('81202.0000')),
#  (12, 'Davies, Ward & Beck', 1, Decimal('1000.0000')),
#  (19, 'Fulbright & Jaworski', 4, Decimal('4950.0000')),
#  (33, 'Swindler & Berlin', 2, Decimal('79960.0000')),
#  (36, 'Troutman Sanders', 1, Decimal('1870.0000')),
#  (41, 'Goulston & Storrs', 1, Decimal('1000.0000')),
#  (42, 'Goodman Phillips & Vineberg', 1, Decimal('1000.0000')),
#  (46, 'Robinson Silverman Pearce Aronsohn & Berman', 1, Decimal('3900.0000')),
#  (50, 'Schreck Morris', 1, Decimal('19500.0000')),
#  (62, 'Hughes Hubbard & Reed', 1, Decimal('12000.0000')),
#  (64, 'Hunton & Williams', 1, Decimal('1080.0000')),
#  (65, 'Hutchins, Wheeler & Ditmar', 1, Decimal('1230.0000')),
#  (66, 'Fried, Frank, Harris, Shriver & Jacobson', 25, Decimal('151823.0000')),
#  (67, 'Richards, Layton & Finger', 38, Decimal('208889.0000')),
# ...
